# %%
# Workaround to use src modules
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
# Library imports
import imageio
import numpy as np
import matplotlib.pyplot as plt

# Functions Imports
from src.utils import test
from src.visualizations import visualize_bitshift_images

# %% [markdown]
# ### Objetivo
#
# Implementar os métodos de segmentação de imagem que irão ajudar na quebra da imagem em regiões planas de cores a serem coloridas pelo usuário :3

# %%
imagem_samp = imageio.imread('../images/raw/3d_woman.png').astype(np.uint8)
visualize_bitshift_images(imagem_samp)
